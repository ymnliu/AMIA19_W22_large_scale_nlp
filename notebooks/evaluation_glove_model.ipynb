# %%
import sys
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from nltk.tokenize import TreebankWordTokenizer
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support
pd.set_option('display.max_colwidth', -1)
pd.options.display.max_rows = 999
np.set_printoptions(threshold=sys.maxsize)

# %%
glove_input_file = '../models/w2v_glove_300.txt'
word2vec_output_file = 'w2v.txt'
glove2word2vec(glove_input_file, word2vec_output_file)
model = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)

# %%
w1 ="stroke"
print(model.most_similar(positive = w1, topn = 6))
#model.most_similar_cosmul(positive=['hepatoma', 'brain'], negative=['liver'])
# Out:
# [('heart', 0.4828336238861084), ('cardiac', 0.45815250277519226), ('debilitating', 0.4523412585258484), ('infarction', 0.4387247562408447), ('illness', 0.4336370527744293), ('complications', 0.43345579504966736)]

# %%
file = "../data/stopwords.txt"
with open(file) as f:
    stop_words = f.read().splitlines()

print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now']

# %%
def sentence_vector(sentence):
    word_list = TreebankWordTokenizer().tokenize(sentence)
    word_list = [word for word in word_list if word not in stop_words]
    word_vectors = []
    for x in word_list:
        try:
            word_vectors.append(model[x])
        except KeyError:
            None    
    return sum(word_vectors)/len(word_vectors)

def vector_breakage(sentence):
    word_list = TreebankWordTokenizer().tokenize(sentence)
    word_list = [word for word in word_list if word not in stop_words]
    word_vectors_list = []
    for x in word_list:
        try:
            if len(model[x])==200:
                word_vectors_list.append(x)
        except:
            None
        else:
            None
    return word_vectors_list

# %%
# load prepartitioned train/test sets
test = pd.read_csv("../data/test.csv")
train = pd.read_csv("../data/AMIA_train_set.csv")

#print(train)

# load full data set
frames = [test, train]
df = pd.concat(frames)
df = df[['text','expansion']]
df['vec'] = [sentence_vector(x) for x in df.text]
df.expansion.unique()

test = test[['text','expansion', 'case']]
train = train[['text','expansion']]
test['vec'] = [sentence_vector(x) for x in test.text]
train['vec'] = [sentence_vector(x) for x in train.text]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X = list(df.vec)
X = np.array(X)
y = df.expansion

X1 = list(train.vec)
X_train = np.array(X1)
y_train = train.expansion

X2 = list(test.vec)
X_test = np.array(X2)
y_test = test.expansion

# %%
# Define classifiers:
svc = SVC(C=1.0, kernel='linear', degree=1).fit(X_train, y_train)
logistic = LogisticRegression().fit(X_train, y_train)

# %%
# SVM results
pred = svc.predict(X_test)
cm = confusion_matrix(y_test, pred,labels=list(set(df.expansion)))
cross_val_scores = cross_val_score(clf, X, y, cv=7)

predicted_expansion = list(pred)
case = test['case'].tolist()

results = pd.DataFrame(
    {'case': case,
     'expansion': predicted_expansion
    })

#print(results)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=7.
#   % (min_groups, self.n_splits)), Warning)

# %%
print('accuracy: {}'.format(cross_val_scores))
print()
#print(set(df.expansion))
#print([len(df[df.expansion == x]) for x in set(df.expansion)])
print()
#print(cm)
print()
print(f1_score(y_test,pred,average = 'weighted'))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=7.
#   % (min_groups, self.n_splits)), Warning)
#            case                          expansion
# 0    26043_OR    operating room
# 1    26272_OR    magnetic resonance
# 2    19905_IT    magnetic resonance
# 3    19749_IT    operating room
# 4    26095_OR    ultrasound
# 5    36650_US    United States
# 6    22809_MR    mitral regurgitation
# 7    22752_MR    mitral regurgitation
# 8    26358_OR    operating room
# 9    23977_MS    morphine sulfate
# 10   19624_IT    multiple sclerosis
# 11   36856_US    United States
# 12   19833_IT    intrathecal
# 13   22592_MR    mitral regurgitation
# 14   22822_MR    magnetic resonance
# 15   21726_MOM   GENERAL ENGLISH
# 16   19714_IT    United States
# 17   36593_US    United States
# 18   26398_OR    operating room
# 19   21873_MOM   multiples of median
# 20   23796_MS    multiple sclerosis
# 21   23599_MS    operating room
# 22   21514_MOM   milk of magnesia
# 23   26432_OR    operating room
# 24   15788_FISH  fluorescent in situ hybridization
# 25   36602_US    United States
# 26   15946_FISH  fluorescent in situ hybridization
# 27   22731_MR    magnetic resonance
# 28   36516_US    United States
# 29   22563_MR    multiple sclerosis
# 30   19892_IT    GENERAL ENGLISH
# 31   26389_OR    operating room
# 32   19899_IT    magnetic resonance
# 33   36709_US    United States
# 34   15995_FISH  fluorescent in situ hybridization
# 35   23920_MS    multiple sclerosis
# 36   19851_IT    operating room
# 37   23975_MS    morphine sulfate
# 38   23550_MS    United States
# 39   19878_IT    United States
# 40   36902_US    United States
# 41   22523_MR    magnetic resonance
# 42   15797_FISH  fluorescent in situ hybridization
# 43   22952_MR    operating room
# 44   36520_US    United States
# 45   19871_IT    GENERAL ENGLISH
# 46   36758_US    GENERAL ENGLISH
# 47   23607_MS    United States
# 48   26211_OR    operating room
# 49   26491_OR    operating room
# 50   22818_MR    magnetic resonance
# 51   21958_MOM   multiples of median
# 52   26261_OR    operating room
# 53   22684_MR    mitral regurgitation
# 54   36813_US    GENERAL ENGLISH
# 55   19896_IT    United States
# 56   21802_MOM   multiples of median
# 57   23995_MS    morphine sulfate
# 58   36961_US    fluorescent in situ hybridization
# 59   36829_US    United States
# 60   36987_US    ultrasound
# 61   15509_FISH  GENERAL ENGLISH
# 62   36722_US    United States
# 63   22793_MR    magnetic resonance
# 64   19514_IT    GENERAL ENGLISH
# 65   19723_IT    GENERAL ENGLISH
# 66   15721_FISH  fluorescent in situ hybridization
# 67   15738_FISH  fluorescent in situ hybridization
# 68   22536_MR    magnetic resonance
# 69   19618_IT    GENERAL ENGLISH
# 70   19625_IT    United States
# 71   21734_MOM   multiples of median
# 72   15685_FISH  fluorescent in situ hybridization
# 73   23843_MS    morphine sulfate
# 74   23794_MS    United States
# 75   21649_MOM   multiples of median
# 76   26200_OR    operating room
# 77   22779_MR    magnetic resonance
# 78   21770_MOM   multiples of median
# 79   23570_MS    morphine sulfate
# 80   22743_MR    multiple sclerosis
# 81   26001_OR    operating room
# 82   36802_US    United States
# 83   26208_OR    operating room
# 84   36774_US    United States
# 85   19733_IT    United States
# 86   26165_OR    magnetic resonance
# 87   19587_IT    GENERAL ENGLISH
# 88   15834_FISH  fluorescent in situ hybridization
# 89   21925_MOM   multiples of median
# 90   26161_OR    operating room
# 91   22800_MR    mitral regurgitation
# 92   23524_MS    ultrasound
# 93   19856_IT    GENERAL ENGLISH
# 94   36963_US    multiple sclerosis
# 95   22657_MR    magnetic resonance
# 96   22649_MR    mitral regurgitation
# 97   15851_FISH  fluorescent in situ hybridization
# 98   15989_FISH  fluorescent in situ hybridization
# 99   26062_OR    operating room
# 100  21881_MOM   multiples of median
# 101  36511_US    GENERAL ENGLISH
# 102  21936_MOM   multiples of median
# 103  22575_MR    magnetic resonance
# 104  22946_MR    magnetic resonance
# 105  21665_MOM   multiples of median
# 106  36938_US    operating room
# 107  26266_OR    operating room
# 108  23558_MS    operating room
# 109  26044_OR    ultrasound
# 110  19632_IT    United States
# 111  36989_US    United States
# 112  19521_IT    multiple sclerosis
# 113  21877_MOM   multiples of median
# 114  15838_FISH  fluorescent in situ hybridization
# 115  21675_MOM   multiples of median
# 116  22947_MR    magnetic resonance
# 117  26293_OR    operating room
# 118  19786_IT    information technology
# 119  36660_US    United States
# 120  15942_FISH  fluorescent in situ hybridization
# 121  23810_MS    morphine sulfate
# 122  36609_US    GENERAL ENGLISH
# 123  19503_IT    operating room
# 124  23765_MS    multiple sclerosis
# 125  21598_MOM   multiples of median
# 126  15601_FISH  fluorescent in situ hybridization
# 127  21637_MOM   multiples of median
# 128  15755_FISH  fluorescent in situ hybridization
# 129  23694_MS    multiple sclerosis
# 130  19722_IT    multiple sclerosis
# 131  26016_OR    United States
# 132  21522_MOM   GENERAL ENGLISH
# 133  15539_FISH  GENERAL ENGLISH
# 134  36642_US    United States
# 135  21848_MOM   multiples of median
# 136  22968_MR    mitral regurgitation
# 137  23909_MS    United States
# 138  36708_US    GENERAL ENGLISH
# 139  21542_MOM   GENERAL ENGLISH
# 140  19687_IT    morphine sulfate
# 141  23643_MS    morphine sulfate
# 142  15662_FISH  fluorescent in situ hybridization
# 143  15555_FISH  fluorescent in situ hybridization
# 144  15702_FISH  fluorescent in situ hybridization
# 145  15912_FISH  fluorescent in situ hybridization
# 146  26282_OR    operating room
# 147  26338_OR    GENERAL ENGLISH
# 148  26228_OR    operating room
# 149  15784_FISH  fluorescent in situ hybridization
# 150  22899_MR    magnetic resonance
# 151  36536_US    multiple sclerosis
# 152  15916_FISH  fluorescent in situ hybridization
# 153  15676_FISH  fluorescent in situ hybridization
# 154  19785_IT    United States
# 155  15518_FISH  operating room
# 156  21816_MOM   multiples of median
# 157  21505_MOM   morphine sulfate
# 158  23650_MS    GENERAL ENGLISH
# 159  15580_FISH  fluorescent in situ hybridization
# 160  23863_MS    operating room
# 161  21937_MOM   multiples of median
# 162  15629_FISH  fluorescent in situ hybridization
# 163  19762_IT    United States
# 164  19540_IT    intrathecal
# 165  19579_IT    GENERAL ENGLISH
# 166  21718_MOM   multiples of median
# 167  22627_MR    magnetic resonance
# 168  22518_MR    mitral regurgitation
# 169  21580_MOM   multiples of median
# 170  22725_MR    mitral regurgitation
# 171  22913_MR    magnetic resonance
# 172  15829_FISH  fluorescent in situ hybridization
# 173  36764_US    United States
# 174  23508_MS    multiple sclerosis
# 175  21865_MOM   multiples of median
# 176  26369_OR    operating room
# 177  21561_MOM   multiples of median
# 178  21694_MOM   multiples of median
# 179  26059_OR    operating room
# 180  21813_MOM   multiples of median
# 181  23654_MS    operating room
# 182  23864_MS    GENERAL ENGLISH
# 183  36634_US    United States
# 184  22985_MR    magnetic resonance
# 185  22704_MR    magnetic resonance
# 186  23830_MS    ultrasound
# 187  23848_MS    fluorescent in situ hybridization
# 188  26058_OR    operating room
# 189  22670_MR    mitral regurgitation
# 190  26270_OR    fluorescent in situ hybridization
# 191  21826_MOM   multiples of median
# 192  36854_US    United States
# 193  26034_OR    morphine sulfate
# 194  21923_MOM   multiples of median
# 195  26113_OR    operating room
# 196  19730_IT    GENERAL ENGLISH
# 197  23931_MS    GENERAL ENGLISH
# 198  19830_IT    operating room
# 199  36941_US    United States
# 200  21549_MOM   multiples of median
# 201  22574_MR    magnetic resonance
# 202  19597_IT    multiple sclerosis
# 203  26475_OR    GENERAL ENGLISH
# 204  36861_US    morphine sulfate
# 205  19654_IT    United States
# 206  19630_IT    operating room
# 207  15728_FISH  United States
# 208  36808_US    United States
# 209  22944_MR    magnetic resonance
# 210  26267_OR    operating room
# 211  19799_IT    GENERAL ENGLISH
# 212  23513_MS    multiple sclerosis
# 213  15822_FISH  fluorescent in situ hybridization
# 214  23556_MS    morphine sulfate
# 215  26444_OR    operating room
# 216  26326_OR    magnetic resonance
# 217  23646_MS    morphine sulfate
# 218  15856_FISH  fluorescent in situ hybridization
# 219  21679_MOM   multiples of median
# 220  21541_MOM   milk of magnesia
# 221  15688_FISH  fluorescent in situ hybridization
# 222  23763_MS    operating room
# 223  36529_US    United States
# 224  19538_IT    GENERAL ENGLISH
# 225  36707_US    United States
# 226  36990_US    operating room
# 227  23984_MS    multiple sclerosis
# 228  15549_FISH  fluorescent in situ hybridization
# 229  23691_MS    morphine sulfate
# 230  36694_US    United States
# 231  21888_MOM   multiples of median
# 232  22720_MR    mitral regurgitation
# 233  21933_MOM   multiples of median
# 234  15955_FISH  fluorescent in situ hybridization
# 235  23545_MS    United States
# 236  36723_US    United States
# 237  21822_MOM   multiples of median
# 238  22965_MR    GENERAL ENGLISH
# 239  26328_OR    fluorescent in situ hybridization
# 240  36873_US    multiple sclerosis
# 241  26426_OR    operating room
# 242  21781_MOM   multiples of median
# 243  22880_MR    magnetic resonance
# 244  19550_IT    operating room
# 245  26197_OR    operating room
# 246  36826_US    United States
# 247  15935_FISH  fluorescent in situ hybridization
# 248  23881_MS    GENERAL ENGLISH
# 249  21979_MOM   multiples of median
# 250  26370_OR    GENERAL ENGLISH
# 251  26245_OR    operating room
# 252  19880_IT    United States
# 253  22669_MR    mitral regurgitation
# 254  26049_OR    operating room
# 255  23862_MS    morphine sulfate
# 256  19531_IT    operating room
# 257  22790_MR    magnetic resonance
# 258  23896_MS    magnetic resonance
# 259  21643_MOM   multiples of median
# 260  36603_US    United States
# 261  36949_US    ultrasound
# 262  23901_MS    United States
# 263  15759_FISH  fluorescent in situ hybridization
# 264  19771_IT    GENERAL ENGLISH
# 265  19586_IT    GENERAL ENGLISH
# 266  23889_MS    GENERAL ENGLISH
# 267  36649_US    United States
# 268  23916_MS    morphine sulfate
# 269  23617_MS    morphine sulfate
# 270  22532_MR    GENERAL ENGLISH
# 271  23604_MS    United States
# 272  22508_MR    mitral regurgitation
# 273  21662_MOM   multiples of median
# 274  36951_US    United States
# 275  23555_MS    milk of magnesia
# 276  36898_US    multiple sclerosis
# 277  22726_MR    mitral regurgitation
# 278  15571_FISH  fluorescent in situ hybridization
# 279  19631_IT    operating room
# 280  23979_MS    morphine sulfate
# 281  15823_FISH  GENERAL ENGLISH
# 282  15511_FISH  fluorescent in situ hybridization
# 283  21939_MOM   multiples of median
# 284  23784_MS    GENERAL ENGLISH
# 285  36884_US    United States
# 286  22693_MR    magnetic resonance
# 287  36730_US    United States
# 288  19740_IT    operating room
# 289  19718_IT    iliotibial
# 290  19758_IT    GENERAL ENGLISH
# 291  36864_US    United States
# 292  19744_IT    information technology
# 293  21601_MOM   multiples of median
# 294  19815_IT    GENERAL ENGLISH
# 295  22916_MR    magnetic resonance
# 296  15768_FISH  fluorescent in situ hybridization
# 297  23647_MS    morphine sulfate
# 298  22580_MR    mitral regurgitation
# 299  21947_MOM   multiples of median
# 300  22533_MR    mitral regurgitation
# 301  26295_OR    GENERAL ENGLISH
# 302  26332_OR    operating room
# 303  22755_MR    magnetic resonance
# 304  15683_FISH  fluorescent in situ hybridization
# 305  21686_MOM   multiples of median
# 306  23573_MS    morphine sulfate
# 307  21676_MOM   multiples of median
# 308  21506_MOM   GENERAL ENGLISH
# 309  22736_MR    United States
# 310  36606_US    operating room
# 311  15952_FISH  fluorescent in situ hybridization
# 312  23781_MS    morphine sulfate
# 313  36955_US    fluorescent in situ hybridization
# 314  15704_FISH  fluorescent in situ hybridization
# 315  22950_MR    magnetic resonance
# 316  23711_MS    magnetic resonance
# 317  26187_OR    GENERAL ENGLISH
# 318  26276_OR    operating room
# 319  15991_FISH  fluorescent in situ hybridization
# 320  15553_FISH  fluorescent in situ hybridization
# 321  26414_OR    operating room
# 322  23684_MS    morphine sulfate
# 323  19805_IT    United States
# 324  22545_MR    mitral regurgitation
# 325  22506_MR    magnetic resonance
# 326  22645_MR    magnetic resonance
# 327  21552_MOM   multiples of median
# 328  26470_OR    operating room
# 329  21712_MOM   multiples of median
# 330  36699_US    United States
# 331  26128_OR    operating room
# 332  23527_MS    morphine sulfate
# 333  15606_FISH  ultrasound
# 334  19826_IT    United States
# 335  26445_OR    ischial tuberosity
# 336  15858_FISH  United States
# 337  36547_US    multiple sclerosis
# 338  19585_IT    operating room
# 339  15693_FISH  fluorescent in situ hybridization
# 340  15911_FISH  fluorescent in situ hybridization
# 341  22864_MR    GENERAL ENGLISH
# 342  21833_MOM   multiples of median
# 343  26320_OR    ischial tuberosity
# 344  21796_MOM   multiples of median
# 345  15625_FISH  fluorescent in situ hybridization
# 346  19626_IT    operating room
# 347  15751_FISH  fluorescent in situ hybridization
# 348  26193_OR    operating room
# 349  26334_OR    operating room

# %%
# LogisticRegression results
pred = logisic.predict(X_test)
cm = confusion_matrix(y_test, pred,labels=list(set(df.expansion)))
cross_val_scores = cross_val_score(clf, X, y, cv=7)

predicted_expansion = list(pred)
case = test['case'].tolist()

results = pd.DataFrame(
    {'case': case,
     'expansion': predicted_expansion
    })

#print(results)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=7.
#   % (min_groups, self.n_splits)), Warning)
#            case                          expansion
# 0    26043_OR    operating room
# 1    26272_OR    magnetic resonance
# 2    19905_IT    multiple sclerosis
# 3    19749_IT    operating room
# 4    26095_OR    operating room
# 5    36650_US    United States
# 6    22809_MR    mitral regurgitation
# 7    22752_MR    mitral regurgitation
# 8    26358_OR    operating room
# 9    23977_MS    morphine sulfate
# 10   19624_IT    operating room
# 11   36856_US    United States
# 12   19833_IT    operating room
# 13   22592_MR    mitral regurgitation
# 14   22822_MR    magnetic resonance
# 15   21726_MOM   GENERAL ENGLISH
# 16   19714_IT    United States
# 17   36593_US    United States
# 18   26398_OR    fluorescent in situ hybridization
# 19   21873_MOM   multiples of median
# 20   23796_MS    multiple sclerosis
# 21   23599_MS    GENERAL ENGLISH
# 22   21514_MOM   milk of magnesia
# 23   26432_OR    mitral regurgitation
# 24   15788_FISH  fluorescent in situ hybridization
# 25   36602_US    United States
# 26   15946_FISH  fluorescent in situ hybridization
# 27   22731_MR    magnetic resonance
# 28   36516_US    United States
# 29   22563_MR    mitral regurgitation
# 30   19892_IT    GENERAL ENGLISH
# 31   26389_OR    operating room
# 32   19899_IT    magnetic resonance
# 33   36709_US    United States
# 34   15995_FISH  fluorescent in situ hybridization
# 35   23920_MS    multiple sclerosis
# 36   19851_IT    operating room
# 37   23975_MS    morphine sulfate
# 38   23550_MS    United States
# 39   19878_IT    United States
# 40   36902_US    United States
# 41   22523_MR    magnetic resonance
# 42   15797_FISH  fluorescent in situ hybridization
# 43   22952_MR    magnetic resonance
# 44   36520_US    United States
# 45   19871_IT    GENERAL ENGLISH
# 46   36758_US    GENERAL ENGLISH
# 47   23607_MS    United States
# 48   26211_OR    operating room
# 49   26491_OR    operating room
# 50   22818_MR    magnetic resonance
# 51   21958_MOM   multiples of median
# 52   26261_OR    operating room
# 53   22684_MR    mitral regurgitation
# 54   36813_US    GENERAL ENGLISH
# 55   19896_IT    United States
# 56   21802_MOM   multiples of median
# 57   23995_MS    morphine sulfate
# 58   36961_US    fluorescent in situ hybridization
# 59   36829_US    United States
# 60   36987_US    ultrasound
# 61   15509_FISH  GENERAL ENGLISH
# 62   36722_US    United States
# 63   22793_MR    magnetic resonance
# 64   19514_IT    GENERAL ENGLISH
# 65   19723_IT    GENERAL ENGLISH
# 66   15721_FISH  fluorescent in situ hybridization
# 67   15738_FISH  fluorescent in situ hybridization
# 68   22536_MR    magnetic resonance
# 69   19618_IT    GENERAL ENGLISH
# 70   19625_IT    United States
# 71   21734_MOM   multiples of median
# 72   15685_FISH  fluorescent in situ hybridization
# 73   23843_MS    morphine sulfate
# 74   23794_MS    United States
# 75   21649_MOM   multiples of median
# 76   26200_OR    operating room
# 77   22779_MR    magnetic resonance
# 78   21770_MOM   multiples of median
# 79   23570_MS    morphine sulfate
# 80   22743_MR    multiple sclerosis
# 81   26001_OR    operating room
# 82   36802_US    United States
# 83   26208_OR    operating room
# 84   36774_US    United States
# 85   19733_IT    information technology
# 86   26165_OR    operating room
# 87   19587_IT    GENERAL ENGLISH
# 88   15834_FISH  fluorescent in situ hybridization
# 89   21925_MOM   multiples of median
# 90   26161_OR    operating room
# 91   22800_MR    mitral regurgitation
# 92   23524_MS    operating room
# 93   19856_IT    GENERAL ENGLISH
# 94   36963_US    multiple sclerosis
# 95   22657_MR    magnetic resonance
# 96   22649_MR    mitral regurgitation
# 97   15851_FISH  fluorescent in situ hybridization
# 98   15989_FISH  fluorescent in situ hybridization
# 99   26062_OR    operating room
# 100  21881_MOM   multiples of median
# 101  36511_US    GENERAL ENGLISH
# 102  21936_MOM   multiples of median
# 103  22575_MR    magnetic resonance
# 104  22946_MR    magnetic resonance
# 105  21665_MOM   multiples of median
# 106  36938_US    operating room
# 107  26266_OR    operating room
# 108  23558_MS    iliotibial
# 109  26044_OR    operating room
# 110  19632_IT    United States
# 111  36989_US    United States
# 112  19521_IT    multiple sclerosis
# 113  21877_MOM   multiples of median
# 114  15838_FISH  fluorescent in situ hybridization
# 115  21675_MOM   multiples of median
# 116  22947_MR    magnetic resonance
# 117  26293_OR    operating room
# 118  19786_IT    information technology
# 119  36660_US    United States
# 120  15942_FISH  fluorescent in situ hybridization
# 121  23810_MS    morphine sulfate
# 122  36609_US    GENERAL ENGLISH
# 123  19503_IT    morphine sulfate
# 124  23765_MS    magnetic resonance
# 125  21598_MOM   multiples of median
# 126  15601_FISH  fluorescent in situ hybridization
# 127  21637_MOM   multiples of median
# 128  15755_FISH  fluorescent in situ hybridization
# 129  23694_MS    multiple sclerosis
# 130  19722_IT    multiple sclerosis
# 131  26016_OR    United States
# 132  21522_MOM   GENERAL ENGLISH
# 133  15539_FISH  fluorescent in situ hybridization
# 134  36642_US    United States
# 135  21848_MOM   multiples of median
# 136  22968_MR    mitral regurgitation
# 137  23909_MS    operating room
# 138  36708_US    operating room
# 139  21542_MOM   milk of magnesia
# 140  19687_IT    morphine sulfate
# 141  23643_MS    morphine sulfate
# 142  15662_FISH  fluorescent in situ hybridization
# 143  15555_FISH  fluorescent in situ hybridization
# 144  15702_FISH  fluorescent in situ hybridization
# 145  15912_FISH  fluorescent in situ hybridization
# 146  26282_OR    operating room
# 147  26338_OR    GENERAL ENGLISH
# 148  26228_OR    operating room
# 149  15784_FISH  fluorescent in situ hybridization
# 150  22899_MR    magnetic resonance
# 151  36536_US    fluorescent in situ hybridization
# 152  15916_FISH  fluorescent in situ hybridization
# 153  15676_FISH  fluorescent in situ hybridization
# 154  19785_IT    fluorescent in situ hybridization
# 155  15518_FISH  operating room
# 156  21816_MOM   multiples of median
# 157  21505_MOM   operating room
# 158  23650_MS    operating room
# 159  15580_FISH  United States
# 160  23863_MS    operating room
# 161  21937_MOM   multiples of median
# 162  15629_FISH  fluorescent in situ hybridization
# 163  19762_IT    United States
# 164  19540_IT    operating room
# 165  19579_IT    GENERAL ENGLISH
# 166  21718_MOM   multiples of median
# 167  22627_MR    magnetic resonance
# 168  22518_MR    mitral regurgitation
# 169  21580_MOM   multiples of median
# 170  22725_MR    GENERAL ENGLISH
# 171  22913_MR    magnetic resonance
# 172  15829_FISH  fluorescent in situ hybridization
# 173  36764_US    United States
# 174  23508_MS    multiple sclerosis
# 175  21865_MOM   multiples of median
# 176  26369_OR    operating room
# 177  21561_MOM   multiples of median
# 178  21694_MOM   multiples of median
# 179  26059_OR    operating room
# 180  21813_MOM   multiples of median
# 181  23654_MS    operating room
# 182  23864_MS    GENERAL ENGLISH
# 183  36634_US    United States
# 184  22985_MR    magnetic resonance
# 185  22704_MR    magnetic resonance
# 186  23830_MS    magnetic resonance
# 187  23848_MS    GENERAL ENGLISH
# 188  26058_OR    operating room
# 189  22670_MR    mitral regurgitation
# 190  26270_OR    operating room
# 191  21826_MOM   multiples of median
# 192  36854_US    United States
# 193  26034_OR    operating room
# 194  21923_MOM   multiples of median
# 195  26113_OR    operating room
# 196  19730_IT    United States
# 197  23931_MS    GENERAL ENGLISH
# 198  19830_IT    operating room
# 199  36941_US    United States
# 200  21549_MOM   multiples of median
# 201  22574_MR    magnetic resonance
# 202  19597_IT    multiple sclerosis
# 203  26475_OR    GENERAL ENGLISH
# 204  36861_US    United States
# 205  19654_IT    United States
# 206  19630_IT    operating room
# 207  15728_FISH  operating room
# 208  36808_US    operating room
# 209  22944_MR    magnetic resonance
# 210  26267_OR    operating room
# 211  19799_IT    GENERAL ENGLISH
# 212  23513_MS    multiple sclerosis
# 213  15822_FISH  fluorescent in situ hybridization
# 214  23556_MS    morphine sulfate
# 215  26444_OR    operating room
# 216  26326_OR    magnetic resonance
# 217  23646_MS    morphine sulfate
# 218  15856_FISH  fluorescent in situ hybridization
# 219  21679_MOM   multiples of median
# 220  21541_MOM   milk of magnesia
# 221  15688_FISH  fluorescent in situ hybridization
# 222  23763_MS    operating room
# 223  36529_US    United States
# 224  19538_IT    GENERAL ENGLISH
# 225  36707_US    United States
# 226  36990_US    operating room
# 227  23984_MS    multiple sclerosis
# 228  15549_FISH  fluorescent in situ hybridization
# 229  23691_MS    milk of magnesia
# 230  36694_US    United States
# 231  21888_MOM   multiples of median
# 232  22720_MR    mitral regurgitation
# 233  21933_MOM   multiples of median
# 234  15955_FISH  fluorescent in situ hybridization
# 235  23545_MS    multiple sclerosis
# 236  36723_US    United States
# 237  21822_MOM   multiples of median
# 238  22965_MR    GENERAL ENGLISH
# 239  26328_OR    fluorescent in situ hybridization
# 240  36873_US    multiple sclerosis
# 241  26426_OR    operating room
# 242  21781_MOM   multiples of median
# 243  22880_MR    magnetic resonance
# 244  19550_IT    magnetic resonance
# 245  26197_OR    operating room
# 246  36826_US    United States
# 247  15935_FISH  fluorescent in situ hybridization
# 248  23881_MS    GENERAL ENGLISH
# 249  21979_MOM   multiples of median
# 250  26370_OR    GENERAL ENGLISH
# 251  26245_OR    operating room
# 252  19880_IT    United States
# 253  22669_MR    mitral regurgitation
# 254  26049_OR    operating room
# 255  23862_MS    morphine sulfate
# 256  19531_IT    operating room
# 257  22790_MR    magnetic resonance
# 258  23896_MS    magnetic resonance
# 259  21643_MOM   multiples of median
# 260  36603_US    United States
# 261  36949_US    ultrasound
# 262  23901_MS    morphine sulfate
# 263  15759_FISH  fluorescent in situ hybridization
# 264  19771_IT    GENERAL ENGLISH
# 265  19586_IT    GENERAL ENGLISH
# 266  23889_MS    GENERAL ENGLISH
# 267  36649_US    fluorescent in situ hybridization
# 268  23916_MS    morphine sulfate
# 269  23617_MS    morphine sulfate
# 270  22532_MR    GENERAL ENGLISH
# 271  23604_MS    GENERAL ENGLISH
# 272  22508_MR    mitral regurgitation
# 273  21662_MOM   multiples of median
# 274  36951_US    United States
# 275  23555_MS    milk of magnesia
# 276  36898_US    United States
# 277  22726_MR    mitral regurgitation
# 278  15571_FISH  fluorescent in situ hybridization
# 279  19631_IT    operating room
# 280  23979_MS    morphine sulfate
# 281  15823_FISH  GENERAL ENGLISH
# 282  15511_FISH  fluorescent in situ hybridization
# 283  21939_MOM   multiples of median
# 284  23784_MS    GENERAL ENGLISH
# 285  36884_US    United States
# 286  22693_MR    magnetic resonance
# 287  36730_US    United States
# 288  19740_IT    operating room
# 289  19718_IT    operating room
# 290  19758_IT    GENERAL ENGLISH
# 291  36864_US    United States
# 292  19744_IT    GENERAL ENGLISH
# 293  21601_MOM   multiples of median
# 294  19815_IT    information technology
# 295  22916_MR    magnetic resonance
# 296  15768_FISH  fluorescent in situ hybridization
# 297  23647_MS    morphine sulfate
# 298  22580_MR    mitral regurgitation
# 299  21947_MOM   multiples of median
# 300  22533_MR    mitral regurgitation
# 301  26295_OR    United States
# 302  26332_OR    operating room
# 303  22755_MR    magnetic resonance
# 304  15683_FISH  fluorescent in situ hybridization
# 305  21686_MOM   multiples of median
# 306  23573_MS    morphine sulfate
# 307  21676_MOM   multiples of median
# 308  21506_MOM   GENERAL ENGLISH
# 309  22736_MR    United States
# 310  36606_US    operating room
# 311  15952_FISH  fluorescent in situ hybridization
# 312  23781_MS    morphine sulfate
# 313  36955_US    United States
# 314  15704_FISH  fluorescent in situ hybridization
# 315  22950_MR    magnetic resonance
# 316  23711_MS    multiple sclerosis
# 317  26187_OR    GENERAL ENGLISH
# 318  26276_OR    operating room
# 319  15991_FISH  fluorescent in situ hybridization
# 320  15553_FISH  fluorescent in situ hybridization
# 321  26414_OR    operating room
# 322  23684_MS    morphine sulfate
# 323  19805_IT    United States
# 324  22545_MR    mitral regurgitation
# 325  22506_MR    mitral regurgitation
# 326  22645_MR    magnetic resonance
# 327  21552_MOM   multiples of median
# 328  26470_OR    operating room
# 329  21712_MOM   multiples of median
# 330  36699_US    fluorescent in situ hybridization
# 331  26128_OR    operating room
# 332  23527_MS    morphine sulfate
# 333  15606_FISH  ultrasound
# 334  19826_IT    United States
# 335  26445_OR    operating room
# 336  15858_FISH  United States
# 337  36547_US    multiple sclerosis
# 338  19585_IT    operating room
# 339  15693_FISH  fluorescent in situ hybridization
# 340  15911_FISH  fluorescent in situ hybridization
# 341  22864_MR    GENERAL ENGLISH
# 342  21833_MOM   multiples of median
# 343  26320_OR    ischial tuberosity
# 344  21796_MOM   multiples of median
# 345  15625_FISH  fluorescent in situ hybridization
# 346  19626_IT    operating room
# 347  15751_FISH  fluorescent in situ hybridization
# 348  26193_OR    operating room
# 349  26334_OR    operating room

# %%
print('accuracy: {}'.format(cross_val_scores))
print()
#print(set(df.expansion))
#print([len(df[df.expansion == x]) for x in set(df.expansion)])
print()
#print(cm)
print()
print(f1_score(y_test,pred,average = 'weighted'))
# Out:
# accuracy: [0.69942197 0.68712871 0.687251   0.68336673 0.70445344 0.70325203
#  0.71574642]
#
#
#
# 0.6675536551666332
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
sentence = 'Patient was tested for US, cystic fibrosis and other heritable diseases '

sentence = "Procedure went without complications, and the patient was sent to the \
floor postoperatively after he was extubated in the FISH. Thoracic surgery was consulted \
on the day of surgery. Gastrografin upper GI study performed on admission showed no leak. \
However, the patient was admitted under the care of thoracic surgery team, and he was kept \
n.p.o. and followed up on daily basis for any change in vital signs, chest pain for another \
upper GI swallow study which was done 7 days after his symptoms started. "


sentence = ['she had an US to determine if the baby was good', 'he had an US to determine if there was a mass', 'If the patient continues to require blood transfusions an/or if he becomes hemodynamically unstable he will need to be taken to the OR for cystoscopy with clot evacuation. Since his surgery was so recently performed we would rather try to hold off on this, however, as not to disrupt the anastomosis with his new transplanted kidney.']

for s in sentence:
    print('sentence:', s)
    #print(vector_breakage(sentence))
    print('prediction:', clf.predict(sentence_vector(s).reshape(1, -1)))
    print()

# %% [markdown]
# ## Try

# %%
try_out = ''
print(vector_breakage(try_out))
print(clf.predict(sentence_vector(try_out).reshape(1, -1)))
